# %%
import gymnasium as gym
from gymnasium import spaces
from gymnasium.utils import seeding
import numpy as np
import pygame


class BinpickingPathFindingEnv(gym.Env):
    def __init__(
        self,
        screen_width=800,
        screen_height=600,
        table_width=600,
        table_height=400,
        step_size=15,
        time_limit=1000,
    ):
        super(BinpickingPathFindingEnv, self).__init__()

        self.screen_width = screen_width
        self.screen_height = screen_height
        self.table_width = table_width
        self.table_height = table_height
        self.step_size = step_size
        self.time_limit = time_limit

        self.table_top_left = (
            (self.screen_width - self.table_width) // 2,
            (self.screen_height - self.table_height) // 2,
        )
        self.table_bottom_right = (
            self.table_top_left[0] + self.table_width,
            self.table_top_left[1] + self.table_height,
        )

        # Observation space: object position and all goals
        self.observation_space = spaces.Box(
            low=0, high=max(screen_width, screen_height), shape=(2 + 4 * 2,), dtype=np.float32
        )

        # Action space: 120 discrete angles (3 degrees apart)
        self.action_space = spaces.Discrete(120)

        self.colors = {
            "background": (30, 30, 30),
            "table": (50, 50, 150),
            "object": (0, 255, 0),
            "goal": (255, 0, 0),
        }

        self.goal_size = 50
        self.object_radius = 15
        self.screen = None
        self.clock = None

        self.reset()

    def reset(self, seed=None, options=None):
        if seed is not None:
            self.seed(seed)

        self.object = np.random.rand(2) * [
            self.table_width - 2 * self.object_radius,
            self.table_height - 2 * self.object_radius,
        ]
        self.object += [
            self.table_top_left[0] + self.object_radius,
            self.table_top_left[1] + self.object_radius,
        ]
        self.object = self.object.astype(np.float32)

        top_goal_x = self.table_top_left[0] + self.goal_size // 1.1
        bottom_goal_x = self.table_bottom_right[0] - self.goal_size // 1.1
        top_goal_y = self.table_top_left[1] - self.goal_size // 2
        bottom_goal_y = self.table_bottom_right[1] + self.goal_size // 2

        self.goals = np.array([
            [top_goal_x, top_goal_y],
            [bottom_goal_x, top_goal_y],
            [top_goal_x, bottom_goal_y],
            [bottom_goal_x, bottom_goal_y],
        ]).astype(np.float32)

        distances = np.linalg.norm(self.goals - self.object, axis=1)
        self.closest_goal_index = np.argmin(distances)

        self.time_steps = 0
        return self.get_observation(), {}

    def step(self, action):
        self.time_steps += 1

        # Convert discrete action to angle θ in radians
        theta = action * (2 * np.pi / self.action_space.n)
        # directions = {
        #     0: np.array([1, 0]),    # Right
        #     1: np.array([0, 1]),    # Down
        #     2: np.array([-1, 0]),   # Left
        #     3: np.array([0, -1]),   # Up
        #     4: np.array([1, 1]),    # Down-right
        #     5: np.array([-1, 1]),   # Down-left
        #     6: np.array([-1, -1]),  # Up-left
        #     7: np.array([1, -1]),   # Up-right
        # }
        # move = directions[action] * self.step_size
        # Move the object
        move = np.array([np.cos(theta), np.sin(theta)]) * self.step_size
        new_pos = self.object + move

        reward = 0
        target = self.goals[self.closest_goal_index]
        prev_distance_to_goal = np.linalg.norm(self.object - target)

        if (
            new_pos[0] < self.table_top_left[0]
            or new_pos[0] > self.table_bottom_right[0]
            or new_pos[1] < self.table_top_left[1]
            or new_pos[1] > self.table_bottom_right[1]
        ):
            reward += -10
            done = True
        else:
            self.object = new_pos
            reward += 1

            distance_to_goal = np.linalg.norm(self.object - target)
            distance_change = prev_distance_to_goal - distance_to_goal

            if distance_change > 0:
                reward += 0.5 * distance_change
            elif distance_change < 0:
                reward -= 0.5 * abs(distance_change)

            done = False
            if distance_to_goal < self.goal_size // 2:
                reward += 50
                done = True

        reward += max(0, (self.time_limit - self.time_steps) / self.time_limit)
        truncated = False
        return self.get_observation(), reward, done, truncated, {}

    def render(self, mode="human"):
        if self.screen is None:
            pygame.init()
            self.screen = pygame.display.set_mode((self.screen_width, self.screen_height))
            pygame.display.set_caption("Rectangular Table Pathfinding")
            self.clock = pygame.time.Clock()

        self.screen.fill(self.colors["background"])

        pygame.draw.rect(
            self.screen,
            self.colors["table"],
            pygame.Rect(
                self.table_top_left[0], self.table_top_left[1], self.table_width, self.table_height
            ),
        )

        for i, goal in enumerate(self.goals):
            color = self.colors["goal"] if i == self.closest_goal_index else (100, 100, 100)
            pygame.draw.rect(
                self.screen, 
                color, 
                pygame.Rect(goal[0] - self.goal_size // 2, goal[1] - self.goal_size // 2, self.goal_size, self.goal_size)
            )

        pygame.draw.circle(self.screen, self.colors["object"], self.object.astype(int), self.object_radius)

        pygame.display.flip()
        self.clock.tick(30)

    def close(self):
        if self.screen is not None:
            pygame.quit()

    def get_observation(self):
        return np.concatenate([self.object.flatten(), self.goals.flatten()]).astype(np.float32)

    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return seed

# %%
env = BinpickingPathFindingEnv()

# %%
env.action_space.
# Out:
# 120

# %%
env.get_observation()
# Out:
# array([338.96487, 169.07323, 145.     ,  75.     , 655.     ,  75.     ,
#        145.     , 525.     , 655.     , 525.     ], dtype=float32)

# %%
from stable_baselines3 import PPO, TD3
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import BaseCallback

# Initialize the environment
env = BinpickingPathFindingEnv()

# %%
# Check the environment
check_env(env, warn=True)
# Out:
# /home/bull/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:461: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(

# %%
# Initialize PPO model
model = TD3("MlpPolicy", env, verbose=1)

# Initialize the callback

# Train the model
model.learn(total_timesteps=1000000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.2     |
# |    ep_rew_mean     | 377      |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 320      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 205      |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 29.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 104      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.5     |
# |    ep_rew_mean     | 317      |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 316      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 340      |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 29.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 239      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.2     |
# |    ep_rew_mean     | 223      |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 314      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 375      |
# | train/             |          |
# |    actor_loss      | -22.3    |
# |    critic_loss     | 37.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 274      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.6     |
# |    ep_rew_mean     | 194      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 314      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 442      |
# | train/             |          |
# |    actor_loss      | -23.1    |
# |    critic_loss     | 40.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.5     |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 314      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 490      |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 30.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 389      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.9     |
# |    ep_rew_mean     | 158      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 313      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 549      |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 33.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 448      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 314      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 621      |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 17.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 520      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.5     |
# |    ep_rew_mean     | 156      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 311      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 719      |
# | train/             |          |
# |    actor_loss      | -26.2    |
# |    critic_loss     | 12       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 618      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 311      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 795      |
# | train/             |          |
# |    actor_loss      | -28.3    |
# |    critic_loss     | 22       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 694      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 311      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 851      |
# | train/             |          |
# |    actor_loss      | -26.8    |
# |    critic_loss     | 43.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 750      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 312      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 931      |
# | train/             |          |
# |    actor_loss      | -27      |
# |    critic_loss     | 8.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 830      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | 145      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 313      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1010     |
# | train/             |          |
# |    actor_loss      | -31.4    |
# |    critic_loss     | 9.04     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 909      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 313      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1107     |
# | train/             |          |
# |    actor_loss      | -32.3    |
# |    critic_loss     | 27       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1006     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 313      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1185     |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 6.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1084     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 313      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1325     |
# | train/             |          |
# |    actor_loss      | -35.8    |
# |    critic_loss     | 8.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1224     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 158      |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 312      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1418     |
# | train/             |          |
# |    actor_loss      | -36.2    |
# |    critic_loss     | 24       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1317     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 312      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1498     |
# | train/             |          |
# |    actor_loss      | -37.9    |
# |    critic_loss     | 28.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1397     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 313      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1587     |
# | train/             |          |
# |    actor_loss      | -36.3    |
# |    critic_loss     | 45.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1486     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | 155      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 314      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1658     |
# | train/             |          |
# |    actor_loss      | -37.8    |
# |    critic_loss     | 6.88     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1557     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 315      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1735     |
# | train/             |          |
# |    actor_loss      | -39.6    |
# |    critic_loss     | 30.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1634     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 316      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1806     |
# | train/             |          |
# |    actor_loss      | -38.1    |
# |    critic_loss     | 6.53     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1705     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | 151      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 317      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1878     |
# | train/             |          |
# |    actor_loss      | -40.2    |
# |    critic_loss     | 7.85     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1777     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 318      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1946     |
# | train/             |          |
# |    actor_loss      | -43.5    |
# |    critic_loss     | 39.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1845     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 319      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2059     |
# | train/             |          |
# |    actor_loss      | -44.9    |
# |    critic_loss     | 5.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1958     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 320      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2151     |
# | train/             |          |
# |    actor_loss      | -42      |
# |    critic_loss     | 8.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2050     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | 141      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 321      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2206     |
# | train/             |          |
# |    actor_loss      | -42.5    |
# |    critic_loss     | 5.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2105     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.2     |
# |    ep_rew_mean     | 135      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 321      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2264     |
# | train/             |          |
# |    actor_loss      | -42.4    |
# |    critic_loss     | 6.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2163     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | 136      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 322      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2316     |
# | train/             |          |
# |    actor_loss      | -44.3    |
# |    critic_loss     | 9.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2215     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | 137      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 322      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2385     |
# | train/             |          |
# |    actor_loss      | -43.6    |
# |    critic_loss     | 11.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2284     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.6     |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 323      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2447     |
# | train/             |          |
# |    actor_loss      | -47.1    |
# |    critic_loss     | 6.98     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2346     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 323      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2549     |
# | train/             |          |
# |    actor_loss      | -47.8    |
# |    critic_loss     | 7.83     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2448     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | 141      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 323      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2609     |
# | train/             |          |
# |    actor_loss      | -46.9    |
# |    critic_loss     | 50.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2508     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | 139      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 324      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2689     |
# | train/             |          |
# |    actor_loss      | -49.3    |
# |    critic_loss     | 85.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2588     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | 141      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 325      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2794     |
# | train/             |          |
# |    actor_loss      | -52.1    |
# |    critic_loss     | 6.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2693     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 325      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2865     |
# | train/             |          |
# |    actor_loss      | -54.2    |
# |    critic_loss     | 11.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2764     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 326      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2963     |
# | train/             |          |
# |    actor_loss      | -51.2    |
# |    critic_loss     | 10.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2862     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 146      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 326      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 3075     |
# | train/             |          |
# |    actor_loss      | -52.4    |
# |    critic_loss     | 17.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2974     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 326      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 3222     |
# | train/             |          |
# |    actor_loss      | -57.6    |
# |    critic_loss     | 10.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3121     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 326      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 3278     |
# | train/             |          |
# |    actor_loss      | -55.9    |
# |    critic_loss     | 6.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3177     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | 141      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 327      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 3357     |
# | train/             |          |
# |    actor_loss      | -59.7    |
# |    critic_loss     | 9.36     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3256     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 327      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 3438     |
# | train/             |          |
# |    actor_loss      | -60      |
# |    critic_loss     | 17.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3337     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 139      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 327      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 3516     |
# | train/             |          |
# |    actor_loss      | -59.7    |
# |    critic_loss     | 9.63     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3415     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | 141      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 327      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 3628     |
# | train/             |          |
# |    actor_loss      | -62      |
# |    critic_loss     | 11.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3527     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 327      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 3755     |
# | train/             |          |
# |    actor_loss      | -61.1    |
# |    critic_loss     | 7.79     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3654     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 327      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 3836     |
# | train/             |          |
# |    actor_loss      | -56.5    |
# |    critic_loss     | 13.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3735     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 328      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 3921     |
# | train/             |          |
# |    actor_loss      | -59.9    |
# |    critic_loss     | 7.37     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3820     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 328      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 4029     |
# | train/             |          |
# |    actor_loss      | -64.2    |
# |    critic_loss     | 7.89     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3928     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | 151      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 328      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 4090     |
# | train/             |          |
# |    actor_loss      | -59.2    |
# |    critic_loss     | 5.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3989     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | 146      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 328      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 4160     |
# | train/             |          |
# |    actor_loss      | -57.1    |
# |    critic_loss     | 20.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4059     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | 145      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 328      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 4235     |
# | train/             |          |
# |    actor_loss      | -61.8    |
# |    critic_loss     | 16.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4134     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 329      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 4341     |
# | train/             |          |
# |    actor_loss      | -66.7    |
# |    critic_loss     | 7.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4240     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 329      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 4441     |
# | train/             |          |
# |    actor_loss      | -65.1    |
# |    critic_loss     | 13.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4340     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 329      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 4530     |
# | train/             |          |
# |    actor_loss      | -68.3    |
# |    critic_loss     | 8.7      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4429     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 156      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 330      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 4599     |
# | train/             |          |
# |    actor_loss      | -67.4    |
# |    critic_loss     | 5.51     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4498     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 156      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 329      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 4672     |
# | train/             |          |
# |    actor_loss      | -69      |
# |    critic_loss     | 120      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4571     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 329      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 4745     |
# | train/             |          |
# |    actor_loss      | -68.4    |
# |    critic_loss     | 8.94     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4644     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 155      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 329      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 4818     |
# | train/             |          |
# |    actor_loss      | -66.3    |
# |    critic_loss     | 5.67     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4717     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 329      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 4904     |
# | train/             |          |
# |    actor_loss      | -66      |
# |    critic_loss     | 5.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4803     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 329      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 4976     |
# | train/             |          |
# |    actor_loss      | -71.8    |
# |    critic_loss     | 9.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4875     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 158      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 328      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 5088     |
# | train/             |          |
# |    actor_loss      | -69.7    |
# |    critic_loss     | 7.7      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4987     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.3     |
# |    ep_rew_mean     | 160      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 328      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 5195     |
# | train/             |          |
# |    actor_loss      | -70.1    |
# |    critic_loss     | 10.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5094     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 160      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 327      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 5291     |
# | train/             |          |
# |    actor_loss      | -71.3    |
# |    critic_loss     | 11       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5190     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 151      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 327      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 5331     |
# | train/             |          |
# |    actor_loss      | -69.2    |
# |    critic_loss     | 6.95     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5230     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 327      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 5426     |
# | train/             |          |
# |    actor_loss      | -76.6    |
# |    critic_loss     | 5.65     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5325     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 327      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 5499     |
# | train/             |          |
# |    actor_loss      | -77.7    |
# |    critic_loss     | 11.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5398     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | 155      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 326      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 5596     |
# | train/             |          |
# |    actor_loss      | -69.4    |
# |    critic_loss     | 7.93     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5495     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 327      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 5687     |
# | train/             |          |
# |    actor_loss      | -81.6    |
# |    critic_loss     | 6.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5586     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 326      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 5749     |
# | train/             |          |
# |    actor_loss      | -75.9    |
# |    critic_loss     | 5.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5648     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 327      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 5824     |
# | train/             |          |
# |    actor_loss      | -74.7    |
# |    critic_loss     | 6.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5723     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | 146      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 326      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 5889     |
# | train/             |          |
# |    actor_loss      | -73.4    |
# |    critic_loss     | 6.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5788     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | 145      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 326      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 5953     |
# | train/             |          |
# |    actor_loss      | -76      |
# |    critic_loss     | 7.53     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5852     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 325      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 6090     |
# | train/             |          |
# |    actor_loss      | -66.5    |
# |    critic_loss     | 6.69     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5989     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 325      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 6154     |
# | train/             |          |
# |    actor_loss      | -83.7    |
# |    critic_loss     | 5.91     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6053     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | 151      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 324      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 6242     |
# | train/             |          |
# |    actor_loss      | -72.5    |
# |    critic_loss     | 7.84     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6141     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 323      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 6309     |
# | train/             |          |
# |    actor_loss      | -80.9    |
# |    critic_loss     | 5.04     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6208     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 323      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 6389     |
# | train/             |          |
# |    actor_loss      | -77.7    |
# |    critic_loss     | 5.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6288     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 323      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 6479     |
# | train/             |          |
# |    actor_loss      | -79.3    |
# |    critic_loss     | 13.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6378     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 144      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 323      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 6551     |
# | train/             |          |
# |    actor_loss      | -80.3    |
# |    critic_loss     | 6.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6450     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | 145      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 323      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 6629     |
# | train/             |          |
# |    actor_loss      | -67.8    |
# |    critic_loss     | 7.18     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6528     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 323      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 6733     |
# | train/             |          |
# |    actor_loss      | -78      |
# |    critic_loss     | 6.36     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6632     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 323      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 6806     |
# | train/             |          |
# |    actor_loss      | -78.1    |
# |    critic_loss     | 160      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6705     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 323      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 6887     |
# | train/             |          |
# |    actor_loss      | -79.1    |
# |    critic_loss     | 11.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6786     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 323      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 6971     |
# | train/             |          |
# |    actor_loss      | -76      |
# |    critic_loss     | 5.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6870     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 323      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 7065     |
# | train/             |          |
# |    actor_loss      | -84.4    |
# |    critic_loss     | 7.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6964     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 323      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 7140     |
# | train/             |          |
# |    actor_loss      | -76.6    |
# |    critic_loss     | 6.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7039     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 323      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 7204     |
# | train/             |          |
# |    actor_loss      | -77.5    |
# |    critic_loss     | 10.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7103     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 323      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 7283     |
# | train/             |          |
# |    actor_loss      | -79.9    |
# |    critic_loss     | 6.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7182     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | 146      |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 323      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 7381     |
# | train/             |          |
# |    actor_loss      | -76.8    |
# |    critic_loss     | 6.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7280     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | 145      |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 323      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 7460     |
# | train/             |          |
# |    actor_loss      | -80.6    |
# |    critic_loss     | 10.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7359     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 323      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 7511     |
# | train/             |          |
# |    actor_loss      | -77.5    |
# |    critic_loss     | 6.7      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7410     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | 141      |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 323      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 7592     |
# | train/             |          |
# |    actor_loss      | -70.8    |
# |    critic_loss     | 5.74     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7491     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.6     |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 323      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 7652     |
# | train/             |          |
# |    actor_loss      | -81      |
# |    critic_loss     | 6.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7551     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 323      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 7716     |
# | train/             |          |
# |    actor_loss      | -80.1    |
# |    critic_loss     | 5.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7615     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | 141      |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 323      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 7829     |
# | train/             |          |
# |    actor_loss      | -79.3    |
# |    critic_loss     | 5.69     |
# |    learning_rate   | 0.001    |
# ...
# |    fps             | 327      |
# |    time_elapsed    | 1344     |
# |    total_timesteps | 440699   |
# | train/             |          |
# |    actor_loss      | -84.6    |
# |    critic_loss     | 4.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 440598   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | 155      |
# | time/              |          |
# |    episodes        | 21380    |
# |    fps             | 327      |
# |    time_elapsed    | 1344     |
# |    total_timesteps | 440776   |
# | train/             |          |
# |    actor_loss      | -73.5    |
# |    critic_loss     | 4.81     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 440675   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 21384    |
# |    fps             | 327      |
# |    time_elapsed    | 1344     |
# |    total_timesteps | 440841   |
# | train/             |          |
# |    actor_loss      | -83.4    |
# |    critic_loss     | 5.77     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 440740   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 21388    |
# |    fps             | 327      |
# |    time_elapsed    | 1345     |
# |    total_timesteps | 440914   |
# | train/             |          |
# |    actor_loss      | -78.6    |
# |    critic_loss     | 5.55     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 440813   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 21392    |
# |    fps             | 327      |
# |    time_elapsed    | 1345     |
# |    total_timesteps | 440999   |
# | train/             |          |
# |    actor_loss      | -81.3    |
# |    critic_loss     | 5.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 440898   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | 155      |
# | time/              |          |
# |    episodes        | 21396    |
# |    fps             | 327      |
# |    time_elapsed    | 1345     |
# |    total_timesteps | 441076   |
# | train/             |          |
# |    actor_loss      | -73.5    |
# |    critic_loss     | 4.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 440975   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 21400    |
# |    fps             | 327      |
# |    time_elapsed    | 1345     |
# |    total_timesteps | 441152   |
# | train/             |          |
# |    actor_loss      | -82.8    |
# |    critic_loss     | 5.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441051   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 21404    |
# |    fps             | 327      |
# |    time_elapsed    | 1346     |
# |    total_timesteps | 441237   |
# | train/             |          |
# |    actor_loss      | -80      |
# |    critic_loss     | 5.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441136   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 159      |
# | time/              |          |
# |    episodes        | 21408    |
# |    fps             | 327      |
# |    time_elapsed    | 1346     |
# |    total_timesteps | 441361   |
# | train/             |          |
# |    actor_loss      | -80.1    |
# |    critic_loss     | 6.24     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441260   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 160      |
# | time/              |          |
# |    episodes        | 21412    |
# |    fps             | 327      |
# |    time_elapsed    | 1346     |
# |    total_timesteps | 441451   |
# | train/             |          |
# |    actor_loss      | -81.2    |
# |    critic_loss     | 5.84     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441350   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.5     |
# |    ep_rew_mean     | 164      |
# | time/              |          |
# |    episodes        | 21416    |
# |    fps             | 327      |
# |    time_elapsed    | 1347     |
# |    total_timesteps | 441556   |
# | train/             |          |
# |    actor_loss      | -81.3    |
# |    critic_loss     | 5.96     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441455   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.3     |
# |    ep_rew_mean     | 161      |
# | time/              |          |
# |    episodes        | 21420    |
# |    fps             | 327      |
# |    time_elapsed    | 1347     |
# |    total_timesteps | 441636   |
# | train/             |          |
# |    actor_loss      | -88.4    |
# |    critic_loss     | 6.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | 156      |
# | time/              |          |
# |    episodes        | 21424    |
# |    fps             | 327      |
# |    time_elapsed    | 1347     |
# |    total_timesteps | 441684   |
# | train/             |          |
# |    actor_loss      | -89.6    |
# |    critic_loss     | 5.34     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441583   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 21428    |
# |    fps             | 327      |
# |    time_elapsed    | 1347     |
# |    total_timesteps | 441721   |
# | train/             |          |
# |    actor_loss      | -86.4    |
# |    critic_loss     | 5.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441620   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 21432    |
# |    fps             | 327      |
# |    time_elapsed    | 1347     |
# |    total_timesteps | 441795   |
# | train/             |          |
# |    actor_loss      | -77.6    |
# |    critic_loss     | 7.17     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441694   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 21436    |
# |    fps             | 327      |
# |    time_elapsed    | 1347     |
# |    total_timesteps | 441841   |
# | train/             |          |
# |    actor_loss      | -86      |
# |    critic_loss     | 4.65     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441740   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    episodes        | 21440    |
# |    fps             | 327      |
# |    time_elapsed    | 1348     |
# |    total_timesteps | 441935   |
# | train/             |          |
# |    actor_loss      | -79.2    |
# |    critic_loss     | 5.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441834   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | 144      |
# | time/              |          |
# |    episodes        | 21444    |
# |    fps             | 327      |
# |    time_elapsed    | 1348     |
# |    total_timesteps | 442015   |
# | train/             |          |
# |    actor_loss      | -80.6    |
# |    critic_loss     | 4.95     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441914   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    episodes        | 21448    |
# |    fps             | 327      |
# |    time_elapsed    | 1348     |
# |    total_timesteps | 442069   |
# | train/             |          |
# |    actor_loss      | -79.6    |
# |    critic_loss     | 5.96     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 441968   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    episodes        | 21452    |
# |    fps             | 327      |
# |    time_elapsed    | 1348     |
# |    total_timesteps | 442186   |
# | train/             |          |
# |    actor_loss      | -82      |
# |    critic_loss     | 5.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 442085   |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[114], line 7
#       2 model = TD3("MlpPolicy", env, verbose=1)
#       4 # Initialize the callback
#       5
#       6 # Train the model
# ----> 7 model.learn(total_timesteps=1000000)
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/stable_baselines3/td3/td3.py:222, in TD3.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     213 def learn(
#     214     self: SelfTD3,
#     215     total_timesteps: int,
#    (...)
#     220     progress_bar: bool = False,
#     221 ) -> SelfTD3:
# --> 222     return super().learn(
#     223         total_timesteps=total_timesteps,
#     224         callback=callback,
#     225         log_interval=log_interval,
#     226         tb_log_name=tb_log_name,
#     227         reset_num_timesteps=reset_num_timesteps,
#     228         progress_bar=progress_bar,
#     229     )
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/stable_baselines3/td3/td3.py:179, in TD3.train(self, gradient_steps, batch_size)
#     176     target_q_values = replay_data.rewards + (1 - replay_data.dones) * self.gamma * next_q_values
#     178 # Get current Q-values estimates for each critic network
# --> 179 current_q_values = self.critic(replay_data.observations, replay_data.actions)
#     181 # Compute critic loss
#     182 critic_loss = sum(F.mse_loss(current_q, target_q_values) for current_q in current_q_values)
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/stable_baselines3/common/policies.py:977, in ContinuousCritic.forward(self, obs, actions)
#     975     features = self.extract_features(obs, self.features_extractor)
#     976 qvalue_input = th.cat([features, actions], dim=1)
# --> 977 return tuple(q_net(qvalue_input) for q_net in self.q_networks)
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/stable_baselines3/common/policies.py:977, in <genexpr>(.0)
#     975     features = self.extract_features(obs, self.features_extractor)
#     976 qvalue_input = th.cat([features, actions], dim=1)
# --> 977 return tuple(q_net(qvalue_input) for q_net in self.q_networks)
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/binpickingrl/lib/python3.10/site-packages/torch/nn/modules/linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
